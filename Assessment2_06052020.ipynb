# %%
def my_filter(my_func,lst):
    m=[]
    for i in lst:
        if square(i):
            m.append(i)
    return m
print(my_filter((lambda n:n%2==0),[3,4,5,6,7,8]))
# Out:
# [4, 6, 8]

# %%
def myreduce(my_func, lst):
    m = lst[0]
    for item in lst[1:]:
        m = my_func(m, item)
    return m
print(myreduce((lambda a,b:a+b),[6,7,8,4,3]))
# Out:
# 28

# %%
string="adadgild"
print([i.upper() for i in string])
# Out:
# ['A', 'D', 'A', 'D', 'G', 'I', 'L', 'D']

# %%
string=['x','y','z']
print([row*i for i in string for row in range(1,5)])
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
string=['x','y','z']
print([row*i for i in range(1,5) for row in string])
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
lst=[2,3,4]
print([[i+row] for row in range(len(lst)) for i in lst])
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
lst=[2,3,4,5]
print([[i+row for row in range(len(lst))] for i in lst])

# %%
m=(1,2,3)
n=(1,2,3)
print([(i,row) for row in range(1,4) for i in range(1,4)])

# %%
def longestword(lst):
    n=[]
    for i in lst:
        n.append(len(i)) 
    for word in lst:
        if len(word)>=max(n):
            print(word)
    return ("Length of the list is ",len(lst))    
print(longestword(['Python', 'List', 'Length', 'Watermelon','Satheesh']))
# Out:
# Watermelon
# ('Length of the list is ', 5)

# %%
class Shape:
    def __init__(self,no_of_sides):
        self. n =no_of_sides
        self. sides=[0 for i in range(no_of_sides)]
    def inputsides(self):
        self. sides=[float(input("Enter side" + str(i+1)+":" )) for i in range(self.n)]

class Triangle(Shape):
    def __init__(self):
        Shape.__init__(self,3)
    def tofindarea(self):
        a,b,c=self. sides
        s=(a+b+c)/2
        area=(s*(s-a)*(s-b)*(s-c))
        print("The area of triangle is ", round(area,2))
t=Triangle()
t.inputsides()
t.tofindarea()
# Out:
# Enter side1:8
# Enter side2:7
# Enter side3:6
# The area of triangle is  413.44

# %%
def filter_longwords(n,lst):
    num=len(lst)
    m=[]
    for word in lst:
        if len(word)>n:
            m.append(word)
        print(word,"=",len(word))
    else:
        None  
    return m
print(filter_longwords(10,["SatheeshKumar","Apple","Water_melon","12344567890"]))
# Out:
# SatheeshKumar = 13
# Apple = 5
# Water_melon = 11
# 12344567890 = 11
# ['SatheeshKumar', 'Water_melon', '12344567890']

# %%
def length(lst):
    num=len(lst)
    n=[]
    for i in lst:
        n.append(len(i))
    return n 
print(length(["xyz","list","tuple","python"]))
# Out:
# [3, 4, 5, 6]

# %%
def vowels(chr):
    n=["a","e","i","o","u"]
    for i in n:
        if chr==i:
            return True
        else:
            return False
v=input("Enter the string of lenght one: ")
print(vowels(v))
# Out:
# Enter the string of lenght one: r
# False
